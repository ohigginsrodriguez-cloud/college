# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
DATA_PATH = Path.cwd().parent / "data" / "coffe_shop.csv"

df = pd.read_csv(DATA_PATH)

# %%
print(f"Total de arrivals: {df["arrivals"]}")
